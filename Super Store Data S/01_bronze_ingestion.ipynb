# %%
import zipfile

zip_path='/Volumes/workspace/default/data/Sample_ Superstore.csv.zip'
extract_path='/Volumes/workspace/default/data/'
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extarct_path)

# %%
dbutils.fs.ls("dbfs:/Volumes/workspace/default/data")

# %%
df=spark.read.option("quote", '"').option("escape", '"').option("multiLine", "true").csv("/Volumes/workspace/default/data/Sample_ Superstore.csv",header=True,inferSchema=True)
display(df)

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.sales")
df.write.mode("overwrite").saveAsTable("workspace.sales.bronze_superstore")

# %%
df_clean = df.toDF(*[c.replace(" ", "_").replace("-", "_") for c in df.columns])
df_clean.printSchema()

# %%
spark.sql("drop table if exists workspace.sales.bronze_superstore")
df_clean.write.mode("overwrite").saveAsTable("workspace.sales.bronze_superstore")

# %%
spark.table("workspace.sales.bronze_superstore").display()
